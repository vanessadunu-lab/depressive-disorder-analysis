# %% [markdown]
# Project 1: Global Depressive Disorder Analysis (1990-2019)

# %% [markdown]
# Introduction: This project explores mental illness from 1990-2019 using country-level mental health data. This analysis serves to compare mental health data, specifically depressive disorder prevalence, across countries and determine changes or lack of change displayed by the data.

# %%
import pandas as pd
df = pd.read_csv("1- mental-illnesses-prevalence.csv")
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           0.223206
# 1                                           0.222454
# 2                                           0.221751
# 3                                           0.220987
# 4                                           0.220183
#
#    Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           4.996118
# 1                                           4.989290
# 2                                           4.981346
# 3                                           4.976958
# 4                                           4.977782
#
#    Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized  \
# ...

# %% [markdown]
# Data Overview: This dataset contains country-level mental health data prevalence from 1990-2019.

# %%
df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           0.223206
# 1                                           0.222454
# 2                                           0.221751
# 3                                           0.220987
# 4                                           0.220183
#
#    Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           4.996118
# 1                                           4.989290
# 2                                           4.981346
# 3                                           4.976958
# 4                                           4.977782
#
#    Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6420 entries, 0 to 6419
# Data columns (total 8 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   Entity                                                                             6420 non-null   object
#  1   Code                                                                               6150 non-null   object
#  2   Year                                                                               6420 non-null   int64
#  3   Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  6420 non-null   float64
#  4   Depressive disorders (share of population) - Sex: Both - Age: Age-standardized     6420 non-null   float64
# ...

# %%
df.describe()
# Out:
#               Year  \
# count  6420.000000
# mean   2004.500000
# std       8.656116
# min    1990.000000
# 25%    1997.000000
# 50%    2004.500000
# 75%    2012.000000
# max    2019.000000
#
#        Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# count                                        6420.000000
# mean                                            0.266604
# std                                             0.039383
# min                                             0.188416
# 25%                                             0.242267
# 50%                                             0.273477
# 75%                                             0.286575
# max                                             0.462045
#
#        Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# count                                        6420.000000
# mean                                            3.767036
# ...

# %%
df["Depressive disorders (share of population) - Sex: Both - Age: Age-standardized"].mean()
# Out:
# np.float64(3.767035886853583)

# %%
df["Depressive disorders (share of population) - Sex: Both - Age: Age-standardized"].min()
# Out:
# 1.5223331

# %%
df["Depressive disorders (share of population) - Sex: Both - Age: Age-standardized"].max()
# Out:
# 7.6458993

# %% [markdown]
# Data Cleaning:
# Used df.isnull().sum(), but found no problems in the quality of the data.

# %%
df.isnull().sum()
# Out:
# Entity                                                                                 0
# Code                                                                                 270
# Year                                                                                   0
# Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized      0
# Depressive disorders (share of population) - Sex: Both - Age: Age-standardized         0
# Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized            0
# Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized            0
# Eating disorders (share of population) - Sex: Both - Age: Age-standardized             0
# dtype: int64

# %%
df["Depressive disorders (share of population) - Sex: Both - Age: Age-standardized"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Exploratory Analysis: This section explores differences in depressive disorder prevalence across countries and over time.

# %%
df.groupby("Entity")["Depressive disorders (share of population) - Sex: Both - Age: Age-standardized"].mean().sort_values()
# Out:
# Entity
# Brunei                      1.555203
# South Korea                 2.005174
# Japan                       2.113551
# Myanmar                     2.148452
# Poland                      2.206558
#                               ...
# Angola                      5.844577
# Central African Republic    5.979900
# Greenland                   6.287225
# Palestine                   6.663175
# Uganda                      7.142991
# Name: Depressive disorders (share of population) - Sex: Both - Age: Age-standardized, Length: 214, dtype: float64

# %%
bottom10=df.groupby("Entity")["Depressive disorders (share of population) - Sex: Both - Age: Age-standardized"].mean().sort_values().head(10)
bottom10.plot(kind="bar")
plt.title("Bottom 10 Countries by Average Depressive Disorder Prevalence")
plt.show()

# %% [markdown]
# Brunei showed the lowest rate of depressive disorders.

# %%
top10 = df.groupby("Entity")["Depressive disorders (share of population) - Sex: Both - Age: Age-standardized"].mean().sort_values().tail(10)
top10.plot(kind="bar")
plt.title("Top 10 Countries by Average Depressive Disorder Prevalence")
plt.show()

# %% [markdown]
# Uganda showed the highest rate of depressive disorders.

# %%
df[df["Entity"]=="Uganda"]
# Out:
#       Entity Code  Year  \
# 5940  Uganda  UGA  1990
# 5941  Uganda  UGA  1991
# 5942  Uganda  UGA  1992
# 5943  Uganda  UGA  1993
# 5944  Uganda  UGA  1994
# 5945  Uganda  UGA  1995
# 5946  Uganda  UGA  1996
# 5947  Uganda  UGA  1997
# 5948  Uganda  UGA  1998
# 5949  Uganda  UGA  1999
# 5950  Uganda  UGA  2000
# 5951  Uganda  UGA  2001
# 5952  Uganda  UGA  2002
# 5953  Uganda  UGA  2003
# 5954  Uganda  UGA  2004
# 5955  Uganda  UGA  2005
# 5956  Uganda  UGA  2006
# 5957  Uganda  UGA  2007
# 5958  Uganda  UGA  2008
# 5959  Uganda  UGA  2009
# 5960  Uganda  UGA  2010
# 5961  Uganda  UGA  2011
# 5962  Uganda  UGA  2012
# 5963  Uganda  UGA  2013
# 5964  Uganda  UGA  2014
# 5965  Uganda  UGA  2015
# 5966  Uganda  UGA  2016
# 5967  Uganda  UGA  2017
# 5968  Uganda  UGA  2018
# 5969  Uganda  UGA  2019
#
#       Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 5940                                           0.200903
# ...

# %%
import matplotlib.pyplot as plt
country = df[df["Entity"]=="Uganda"]
plt.plot(country["Year"], country["Depressive disorders (share of population) - Sex: Both - Age: Age-standardized"])
plt.title("Depressive disorders Prevalence in Uganda From 1990-2019")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# Uganda showed rates higher than the average of 3.78 (as calculated in the data overview section) and these values remained higher than the two other selected countries for the analysis, Brunei and El Salvador.

# %%
df[df["Entity"]=="Brunei"]
# Out:
#      Entity Code  Year  \
# 870  Brunei  BRN  1990
# 871  Brunei  BRN  1991
# 872  Brunei  BRN  1992
# 873  Brunei  BRN  1993
# 874  Brunei  BRN  1994
# 875  Brunei  BRN  1995
# 876  Brunei  BRN  1996
# 877  Brunei  BRN  1997
# 878  Brunei  BRN  1998
# 879  Brunei  BRN  1999
# 880  Brunei  BRN  2000
# 881  Brunei  BRN  2001
# 882  Brunei  BRN  2002
# 883  Brunei  BRN  2003
# 884  Brunei  BRN  2004
# 885  Brunei  BRN  2005
# 886  Brunei  BRN  2006
# 887  Brunei  BRN  2007
# 888  Brunei  BRN  2008
# 889  Brunei  BRN  2009
# 890  Brunei  BRN  2010
# 891  Brunei  BRN  2011
# 892  Brunei  BRN  2012
# 893  Brunei  BRN  2013
# 894  Brunei  BRN  2014
# 895  Brunei  BRN  2015
# 896  Brunei  BRN  2016
# 897  Brunei  BRN  2017
# 898  Brunei  BRN  2018
# 899  Brunei  BRN  2019
#
#      Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 870                                           0.307496
# 871                                           0.307643
# ...

# %%
import matplotlib.pyplot as plt
country = df[df["Entity"] == "Brunei"]
plt.plot(country["Year"], country["Depressive disorders (share of population) - Sex: Both - Age: Age-standardized"])
plt.title("Depressive disorders Prevalence in Brunei From 1990-2019")
plt.xlabel("Year")
plt.ylabel("Rate")
plt.show()

# %%
import pandas as pd
df = pd.read_csv("1- mental-illnesses-prevalence.csv")

# %%
df[df["Entity"]=="El Salvador"]
# Out:
#            Entity Code  Year  \
# 1770  El Salvador  SLV  1990
# 1771  El Salvador  SLV  1991
# 1772  El Salvador  SLV  1992
# 1773  El Salvador  SLV  1993
# 1774  El Salvador  SLV  1994
# 1775  El Salvador  SLV  1995
# 1776  El Salvador  SLV  1996
# 1777  El Salvador  SLV  1997
# 1778  El Salvador  SLV  1998
# 1779  El Salvador  SLV  1999
# 1780  El Salvador  SLV  2000
# 1781  El Salvador  SLV  2001
# 1782  El Salvador  SLV  2002
# 1783  El Salvador  SLV  2003
# 1784  El Salvador  SLV  2004
# 1785  El Salvador  SLV  2005
# 1786  El Salvador  SLV  2006
# 1787  El Salvador  SLV  2007
# 1788  El Salvador  SLV  2008
# 1789  El Salvador  SLV  2009
# 1790  El Salvador  SLV  2010
# 1791  El Salvador  SLV  2011
# 1792  El Salvador  SLV  2012
# 1793  El Salvador  SLV  2013
# 1794  El Salvador  SLV  2014
# 1795  El Salvador  SLV  2015
# 1796  El Salvador  SLV  2016
# 1797  El Salvador  SLV  2017
# 1798  El Salvador  SLV  2018
# 1799  El Salvador  SLV  2019
#
# ...

# %%
import matplotlib.pyplot as plt
country = df[df["Entity"]=="El Salvador"]
plt.plot(country["Year"], country ["Depressive disorders (share of population) - Sex: Both - Age: Age-standardized"])
plt.title("Depressive disorders Prevalence in El Salvador From 1990-2019")
plt.xlabel("Year")
plt.ylabel("Rate")
plt.show()

# %% [markdown]
# Findings
#
# Top Countries:
# The top 10 countries with highest depressive disorder prevalence are: Democratic Republic of Congo, Gambia, Gabon, Congo, Equatorial Guinea, Angola, Central African Republic, Greenland, Palestine, and Uganda.
#
# Bottom Countries:
# The bottom 10 countries with the lowest depressive disorder prevalence are: Brunei, South Korea, Japan, Myanmar, Poland, Peru, Singapore, Indonesia, Colombia, and Albania.
#
# Comparison Across Three Countries:
# In comparing Uganda, Brunei, and El Salvador, Uganda had the highest depressive disorder rates ranging from 6.4-7.8 followed by El Salvador (rates between 3 and 4) and Brunei (rates between 1.5 and 1.7) which remained the lowest.
#
# Uganda showed the largest overall difference between maximum and minimum values (greater than 1) among the selected countries followed by El Salvador which showed an overall difference (0.3-0.4) while Brunei showed the least overall difference (.08-.1).

# %% [markdown]
# Conclusion: Depressive disorder prevalence was the focus of analysis in this data of mental illness across countries from the time period of 1990-2019. Depressive disorder rates varied across all countries with some countries having less overall changes in rates of depressive disorders across the time period compared to others. This suggests that mental health impacts countries differently. Overall, the analysis of depressive orders in countries across the time period suggest that the level of impact varies from country to country and over a time period.
